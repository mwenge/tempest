# %% [markdown]
# ## Run the Tempest Sound Routine
# ### with the objective of understanding it!

# %% [markdown]
# Compile our little 6502 emulator

# %%
hex(0x5e << 1)
# Out:
# '0xbc'

# %%
# !g++ -o "little_6502_emu" "little_6502_emu.cc" -g -Wall -Wno-misleading-indentation -Wno-implicit-fallthrough    -Wno-unused-result -W -pedantic -Ofast -std=c++0x

# %%
# !g++ -o "little_6502_emu" "little_6502_emu.cc" -g -Wall \
    -Wno-misleading-indentation -Wno-implicit-fallthrough \
    -Wno-unused-result -W -pedantic -Ofast -std=c++0x

# %% [markdown]
# Port the macro assembler sound routine to 64tass-compatible 6502 assembler.

# %%
asm = """
NCHANL = #$10
POKEY = $0000
AUDF1    =POKEY
AUDC1    =POKEY+1
AUDCTL    =POKEY+8
ALLPOT    =POKEY+8
RANDOM    =POKEY+$0A
POTGO    =POKEY+$0B
SKCTL    =POKEY+$0F

STVAL    =0            ;VALUE TO START SEQUENCE
FRCNT    =1            ;# OF FRAMES BEFORE ANY CHANGE
CHANGE    =2            ;AMOUNT OF CHANGE
NUMBER    =3            ;TOTAL NUMBER OF CHANGES IN THIS SEQUENCE

; Put the rest of the code starting at $2000
;
;
; Put the RAM starting at $1000
;
SINDEX = $0B0
POINT = $0C0     
CURRENT = $0D0
FRAMES = $0E0
COUNT = $0F0

JMP RUN_PROG

*=$2000
RUN_PROG:
	LDA #$7F  ; LDA SIDT3		;THRUST IN SPACE
	JSR SNDON
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND
	JSR MODSND

; -----------------------------------------------
; Enable a sound
; -----------------------------------------------
SNDON:
    TAY            ;USE AS INDEX
    LDX NCHANL-1            ;NO.
    
SNDBEGIN                ;--;LOOP FOR EACH 1/2 CHANNEL
    LDA PNTRS,Y
    BEQ NEXT
    
    STX SINDEX
    STA POINT,X        ;IF NOT SET UP POINTER 
    LDA #1
    STA FRAMES,X        ;DUMMY START, NO SOUND
    STA COUNT,X        ;TILL MODSND STORES TO POKEY
    LDA #$FF
    STA SINDEX
    
NEXT:
    DEY
    DEX
    BNE SNDBEGIN
NWSNON:
    RTS

; -----------------------------------------------
; Update the sound
; -----------------------------------------------
MODSND:
    LDX NCHANL-1            ;8 CHANNELS
    
BEGIN:
    LDA POINT,X
    BEQ DONEXT1         ; IGNORE ZERO POINT
    CPX SINDEX
    BEQ DONEXT1         ; IGNORE IF NO SOUND
    DEC FRAMES,X
    BNE DONEXT1         ; IGNORE IF FRAMES NOT FINISHED YET
    DEC COUNT,X
    BNE OLDGROUP       ;MOVE TO NEXT CHANGE GROUP?
    JMP NEXTGROUP
    
DONEXT1
    JMP DONEXT
    
NEXTGROUP:
RESOUN:    
    INC POINT,X        ;YES. START VALUE
    INC POINT,X
    LDA POINT,X
    ASL
    TAY
    BCS SIGNED
    
    LDA SOUND+STVAL,Y
    STA CURRENT,X
    LDA SOUND+NUMBER,Y
    STA COUNT,X
    LDA SOUND+FRCNT,Y
    JMP CHKCHNL
    
SIGNED:
    LDA SOUND+STVAL+100,Y
    STA CURRENT,X
    LDA SOUND+NUMBER+100,Y
    STA COUNT,X
    LDA SOUND+FRCNT+100,Y
    
CHKCHNL:
    STA FRAMES,X
    BNE UPDCHNL            ;CHANNEL STILL ALIVE?
    
    STA POINT,X        ;NO. KILL IT
    
    LDA CURRENT,X
    BEQ UPDCHNL            ;RESTART CHANNEL?
    
    STA POINT,X        ;YES. UPDATE PTR. WITH RESTART LOC
    BNE RESOUN
    
    JMP UPDCHNL
                ;NO. MAKE CHANGE IN OLD GROUP
OLDGROUP:
    ASL
    TAY
    BCS OLDSIGNED
    LDA SOUND+FRCNT,Y
    STA FRAMES,X
    LDA SOUND+CHANGE,Y
    JMP OCHKCHNL
    
OLDSIGNED:
    LDA SOUND+FRCNT+100,Y
    STA FRAMES,X
    LDA SOUND+CHANGE+100,Y
    
OCHKCHNL:
    LDY CURRENT,X
    CLC
    ADC CURRENT,X
    STA CURRENT,X
    TXA
    LSR
    BCC UPDCHNL

    TYA
    EOR CURRENT,X
    AND $F0
    EOR CURRENT,X
    STA CURRENT,X
    
UPDCHNL:
    LDA CURRENT,X        ;UPDATE POKEY AUDIO CHANNEL
    CPX 8
    BCC UPCH
    
    STA AUDCTL,X
    JMP DONEXT
    
UPCH:
    STA AUDF1,X

DONEXT:
    DEX
    BEQ ENDLOOP
    JMP BEGIN
ENDLOOP:
    RTS


SOUND=*-$06
T51F:	.BYTE $C0,8,4,$10
	.BYTE 0,0
T51A:	.BYTE $A6,$20,$F8,4
	.BYTE 0,0
T52F:	.BYTE $40,8,4,$10
	.BYTE 0,0
T52A:	.BYTE $A6,$20,$FE,4
	.BYTE 0,0
;LAUNCH SOUND
LA3F:	.BYTE $10,1,7,$20,0,0
LA3A:	.BYTE $A2,1,$F8,$20,0,0
;DIE

DI1F:
	.BYTE 8,4,$20,$0A
	.BYTE 8,4,1,9
	.BYTE $10,$0D,4,$0C
	.BYTE 0,0
DI1A:
	.BYTE $08,4,0,$0A
	.BYTE $68,4,0,9
	.BYTE $68,$12,$FF,9
	.BYTE 0,0
;BONUS SOUND
WP4F:	.BYTE $40,1,0,1
	.BYTE $40,1,$FF,$40
	.BYTE $30,1,$FF,$30
	.BYTE $20,1,$FF,$20
	.BYTE $18,1,$FF,$18
	.BYTE $14,1,$FF,$14
	.BYTE $12,1,$FF,$12
	.BYTE $10,1,$FF,$10
	.BYTE 0,0
WP4A:	.BYTE $A8,$93,0,2
	.BYTE 0,0
;CURSOR CROSSED A LINE
LO5F:	.BYTE $0F,4,0,1
	.BYTE 0,0
LO5A:	.BYTE $A2,4,$40,1
	.BYTE 0,0
ES8F:	.BYTE 0,3,2,9			;ENEMY SHOT
	.BYTE 0,0
ES8A:	.BYTE 8,3,$FF,9
	.BYTE 0,0
EL7F:	.BYTE $80,1,$E8,5		;ENEMY LINE $DESTRUCTION
	.BYTE 0,0
EL7A:	.BYTE $A1,1,1,5
	.BYTE 0,0
EX2F:	.BYTE 1,8,2,$10		;ENEMY EXPLOSION
	.BYTE 0,0
EX2A:	.BYTE $86,$20,0,4
	.BYTE 0,0
SL1F:	.BYTE $18,4,0,$FF	;SLAM SOUND
	.BYTE 0,0
SL1A:	.BYTE $AF,4,0,$FF
	.BYTE 0,0
T26F:	.BYTE $C0,$02,$FF,$FF		;THRUST SOUND ON TUBE
	.BYTE 0,0
T26A:	.BYTE $28,$02,$00,$F0	;
	.BYTE 0,0
T36F:	.BYTE $10,$0B,1,$40	;THRUST SOUND IN SPACE
	.BYTE 0,0
T36A:	.BYTE $86,$40,0,$0B
	.BYTE 0,0
S31F:	.BYTE $20,$80,0,3,0,0	;3 SECOND WARNING
S31A:	.BYTE $A8,$40,$F8,6,0,0
;PULSATION SOUND ON
PU6F:
	.BYTE $B0,$02,0,$FF
	.BYTE 0,0
PU6A:
	.BYTE $C8,1,2,$FF
	.BYTE $C8,1,2,$FF
	.BYTE 0,0
;
PO6F:				;TURN PULSATION OFF
PO6A:	.BYTE $C0,1,0,1
	.BYTE 0,0
PNTRS:
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $35,$38,$00,$00
.BYTE $00,$00,$00,$00
SIDLO
.BYTE $00,$00,$47,$4A
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
SIDEX
.BYTE $00,$00,$00,$00
.BYTE $0D,$10,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
SIDLA
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$65,$68
.BYTE $00,$00,$00,$00
SIDPU
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$21,$32
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
SIDWP
.BYTE $13,$1A,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
SIDDI
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$53,$56
.BYTE $00,$00,$00,$00
SIDT2
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$59,$5C
.BYTE $00,$00,$00,$00
SIDT3
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$3B,$3E
SIDES
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $41,$44,$00,$00
SIDEL
.BYTE $4D,$50,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
SIDSL
.BYTE $5F,$62,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
SIDS3
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$00,$00
.BYTE $00,$00,$6D,$6D
.BYTE $00,$00,$00,$00
SIDPO

"""
open("tmp.asm",'w').write(asm)
!64tass tmp.asm -q -o tmp.out -L list.txt
# !cat list.txt
# !./little_6502_emu tmp.out
# Out:
# ; 64tass Turbo Assembler Macro V1.56.2625 listing file
# ; 64tass -q -o tmp.out -L list.txt tmp.asm
# ; Mon Nov 25 18:51:55 2024
#
# ;Offset	;Hex		;Monitor	;Source
#
# ;******  Processing input file: tmp.asm
#
# =#$10					NCHANL = #$10
# =$0000					POKEY = $0000
# =$0000					AUDF1    =POKEY
# =1					AUDC1    =POKEY+1
# =8					AUDCTL    =POKEY+8
# =8					ALLPOT    =POKEY+8
# =10					RANDOM    =POKEY+$0A
# =11					POTGO    =POKEY+$0B
# =15					SKCTL    =POKEY+$0F
# =0					STVAL    =0            ;VALUE TO START SEQUENCE
# =1					FRCNT    =1            ;# OF FRAMES BEFORE ANY CHANGE
# =2					CHANGE    =2            ;AMOUNT OF CHANGE
# =3					NUMBER    =3            ;TOTAL NUMBER OF CHANGES IN THIS SEQUENCE
# =$0b0					SINDEX = $0B0
# =$0c0					POINT = $0C0
# =$0d0					CURRENT = $0D0
# =$0e0					FRAMES = $0E0
# =$0f0					COUNT = $0F0
# .0000	4c 00 20	jmp $2000	JMP RUN_PROG
# .2000					RUN_PROG:
# .2000	a9 7f		lda #$7f		LDA #$7F  ; LDA SIDT3		;THRUST IN SPACE
# ...

# %% [markdown]
# ## Scratchpad

# %%
hex((0xa8+0xf8)&0xff),hex((0xa0+0xf8)&0xff),
hex((0xa0+0xf8)&0xff)
# Out:
# ('0xa0', '0x98')

# %% [markdown]
# This is the 3 second warning (trace from MAME):
# ```
# S31F:	.BYTE 20,80,0,3,0,0	;3 SECOND WARNING
# S31A:	.BYTE 0A8,40,0F8,6,0,0
# ```
# ```
# POKEY AUDC1  $a8 (pure)
# POKEY AUDF1 = $20
# POKEY AUDC1  $a0 (pure)
# POKEY AUDC1  $a8 (pure)
# POKEY AUDF1 = $20
# POKEY AUDC1  $a0 (pure)
# POKEY AUDC1  $a8 (pure)
# POKEY AUDF1 = $20
# POKEY AUDC1  $a0 (pure)
# POKEY AUDC1  $00 (poly9/17+poly5)
# POKEY AUDF1 = $00
# ```

# %% [markdown]
# ```
# sudo apt install 64tass
# ```

# %% [markdown]
# Assemble our little assembler snippet using `64tass`.

# %%
open("tmp.asm",'w').write(asm)
!64tass tmp.asm -q -o tmp.out -L list.txt
# !cat list.txt
# Out:
# ; 64tass Turbo Assembler Macro V1.56.2625 listing file
# ; 64tass -q -o tmp.out -L list.txt tmp.asm
# ; Mon Nov 25 13:36:48 2024
#
# ;Offset	;Hex		;Monitor	;Source
#
# ;******  Processing input file: tmp.asm
#
# .0000	ad 53 21	lda $2153	LDA SIDT3		;THRUST IN SPACE
# .0003	a9 7f		lda #$7f	LDA #$7F
# .0005	20 00 20	jsr $2000	JSR SNDON
# .0008	20 20 20	jsr $2020	JSR MODSND
# .2000					SNDON:
# .2000	a8		tay		    TAY            ;USE AS INDEX
# .2001	a2 0f		ldx #$0f	    LDX NCHANL-1            ;NO.
# .2003					SNDBEGIN
# .2003	b9 d3 20	lda $20d3,y	    LDA PNTRS,Y
# .2006	f0 13		beq $201b	    BEQ NEXT
# .2008	8e 40 60	stx $6040	    STX SINDEX
# .200b	9d 00 60	sta $6000,x	    STA POINT,X        ;IF NOT SET UP POINTER
# .200e	a5 01		lda $01		    LDA 1
# .2010	9d 20 60	sta $6020,x	    STA FRAMES,X        ;DUMMY START, NO SOUND
# .2013	9d 30 60	sta $6030,x	    STA COUNT,X        ;TILL MODSND STORES TO POKEY
# .2016	a5 ff		lda $ff		    LDA $FF
# .2018	8d 40 60	sta $6040	    STA SINDEX
# ...

# %% [markdown]
# Run our assembled program.

# %%
# !./little_6502_emu tmp.out
# Out:
# CPU Register Legend:
# C = Carry,    Z = Zero, I = Interrupt, D = Decimal Mode
# V = Overflow, N = Negative
#
# Execution History (Values are after execution.)
#
#                        | CPU Register | Program
# Instruction |  A  X  Y | C Z I D V N  | Counter
# ----------- | -- -- -- | -----------  | -------
# LDA $2153   | 00 00 00 | 0 1 0 0 0 0  | 049155
# LDA #007F   | 7F 00 00 | 0 0 0 0 0 0  | 049157
# JSR $2000   | 7F 00 00 | 0 0 0 0 0 0  | 008192
# TAY         | 7F 00 7F | 0 0 0 0 0 0  | 008193
# LDX #000F   | 7F 0F 7F | 0 0 0 0 0 0  | 008195
# LDA $20D3   | 00 0F 7F | 0 1 0 0 0 0  | 008198
# BEQ $0013   | 00 0F 7F | 0 1 0 0 0 0  | 008219
# DEY         | 00 0F 7E | 0 0 0 0 0 0  | 008220
# DEX         | 00 0E 7E | 0 0 0 0 0 0  | 008221
# BNE $00E4   | 00 0E 7E | 0 0 0 0 0 0  | 008195
# LDA $20D3   | 00 0E 7E | 0 1 0 0 0 0  | 008198
# BEQ $0013   | 00 0E 7E | 0 1 0 0 0 0  | 008219
# DEY         | 00 0E 7D | 0 0 0 0 0 0  | 008220
# DEX         | 00 0D 7D | 0 0 0 0 0 0  | 008221
# ...
